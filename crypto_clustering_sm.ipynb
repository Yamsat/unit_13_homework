# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# !pip install -U altair
# Out:
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 31.7 MB/s eta 0:00:01
# Requirement already satisfied: entrypoints in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.3)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.11.3)
# Requirement already satisfied: pandas>=0.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.1.5)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.19.5)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (3.2.0)
# Requirement already satisfied: toolz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.11.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (21.2.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (58.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (0.18.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema->altair) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema->altair) (3.10.0.2)
# Installing collected packages: altair
# Successfully installed altair-4.1.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import altair as alt

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Create a DataFrame
crypto_df = pd.read_csv('crypto_data.csv', index_col=0)
crypto_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True, :]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df.loc[crypto_df['Algorithm'] != 'N/A', :]

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns='IsTrading')

# %%
# Remove rows with at least 1 null value
crypto_df.dropna(inplace=True)

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[crypto_df['TotalCoinsMined'] != 0, :]

# %%
# Drop rows where there are 'N/A' text values
for i, r in crypto_df.iterrows():
    for j, c in r.iteritems():
        if c == 'N/A':
            crypto_df.drop(index=i, inplace=True)

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coin_name = crypto_df['CoinName'].to_frame()

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns='CoinName')

# %%
# Create dummy variables for text features
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'], drop_first=True)

# %%
# Standardize data
X_standardized = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(X_standardized)

# %%
# Create a DataFrame with the principal components data
pcs_df = pd.DataFrame(crypto_pca, columns=['PC1', 'PC2', 'PC3'], index=crypto_df.index)
pcs_df.head()
# Out:
#            PC1       PC2       PC3
# 42   -0.338559  1.040405 -0.576957
# 404  -0.321881  1.040631 -0.577370
# 1337  2.313831  1.640439 -0.658424
# BTC  -0.145014 -1.322517  0.201948
# ETH  -0.153123 -2.006441  0.402941

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
alt.Chart(df_elbow).mark_line().encode(x="k", y="inertia").properties(title="Elbow Curb")
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model
km = KMeans(n_clusters=4, random_state=0) 
# Fit the model
km.fit(pcs_df)
# Predict clusters
pred = km.predict(pcs_df)
# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([crypto_df, pcs_df, coin_name], axis=1, join='outer')
clustered_df['Class'] = pred
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply       PC1       PC2  \
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.338559  1.040405
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.321881  1.040631
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  2.313831  1.640439
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.145014 -1.322517
# ETH     Ethash       PoW     1.076842e+08               0 -0.153123 -2.006441
#
#            PC3   CoinName  Class
# 42   -0.576957    42 Coin      0
# 404  -0.577370    404Coin      0
# 1337 -0.658424  EliteCoin      0
# BTC   0.201948    Bitcoin      3
# ETH   0.402941   Ethereum      3

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x='PC1',
    y='PC2',
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"]
).interactive().properties(width=400, height=400)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Print the total number of tradable cryptocurrencies
len(clustered_df)
# Out:
# 533

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
total_coins_minded_scaled = StandardScaler().fit_transform(clustered_df['TotalCoinsMined'].values.reshape(-1, 1))
total_coin_supply_scaled = StandardScaler().fit_transform(clustered_df['TotalCoinSupply'].values.reshape(-1, 1))
clustered_df_scaled = clustered_df.copy()
clustered_df_scaled['TotalCoinsMinded'] = total_coins_minded_scaled
clustered_df_scaled['TotalCoinSupply'] = total_coin_supply_scaled

# %%
alt.Chart(clustered_df_scaled).mark_circle(size=60).encode(
    x="TotalCoinsMined", y="TotalCoinSupply", tooltip=['CoinName']
).interactive().properties(width=400, height=400)
# Out:
# alt.Chart(...)

# %%
display(clustered_df_scaled)
# Out:
#         Algorithm ProofType  TotalCoinsMined  TotalCoinSupply       PC1  \
# 42         Scrypt   PoW/PoS     4.199995e+01        -0.152865 -0.338559
# 404        Scrypt   PoW/PoS     1.055185e+09        -0.144996 -0.321881
# 1337          X13   PoW/PoS     2.927942e+10         4.493764  2.313831
# BTC       SHA-256       PoW     1.792718e+07        -0.152554 -0.145014
# ETH        Ethash       PoW     1.076842e+08        -0.152865 -0.153123
# ...           ...       ...              ...              ...       ...
# ZEPH      SHA-256      DPoS     2.000000e+09        -0.123283  2.470871
# GAP        Scrypt   PoW/PoS     1.493105e+07        -0.149167 -0.336602
# BDX   CryptoNight       PoW     9.802226e+08        -0.132154  0.334761
# ZEN      Equihash       PoW     7.296538e+06        -0.152554 -0.135797
# XBC        Scrypt       PoS     1.283270e+05        -0.152850 -0.294493
#
#            PC2       PC3     CoinName  Class  TotalCoinsMinded
# 42    1.040405 -0.576957      42 Coin      0         -0.116748
# 404   1.040631 -0.577370      404Coin      0         -0.093589
# 1337  1.640439 -0.658424    EliteCoin      0          0.525872
# BTC  -1.322517  0.201948      Bitcoin      3         -0.116354
# ETH  -2.006441  0.402941     Ethereum      3         -0.114384
# ...        ...       ...          ...    ...               ...
# ZEPH  0.758166 -0.131220       ZEPHYR      0         -0.072852
# GAP   1.040300 -0.576973      Gapcoin      0         -0.116420
# BDX  -2.306674  0.419676       Beldex      3         -0.095234
# ZEN  -1.978359  0.507056      Horizen      3         -0.116588
# XBC   0.848157 -0.260072  BitcoinPlus      0         -0.116745
#
# [533 rows x 10 columns]
